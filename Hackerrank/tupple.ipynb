# %%
t = (10, 20, 30, 40)
print(t[0])   
print(t[2])
# Out:
# 10
# 30

# %%
print(t[-1])  
print(t[-2])
# Out:
# 40
# 30

# %%
t = (10, 20, 30, 40, 50)
print(t[1:4])  
print(t[:3])    
print(t[::2])
# Out:
# (20, 30, 40)
# (10, 20, 30)
# (10, 30, 50)

# %%
a = (1, 2)
b = (3, 4)
print(a + b)
# Out:
# (1, 2, 3, 4)

# %%
t = (1, 2)
print(t * 3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
t = (5, 10, 15)
print(10 in t)   
print(20 in t)
# Out:
# True
# False

# %%
t = (5, 1, 8, 3)

print(len(t))   
print(max(t))   
print(min(t))   
print(sum(t))
# Out:
# 4
# 8
# 1
# 17

# %%
t = (1, 2, 2, 3)

print(t.count(2))  
print(t.index(1))
# Out:
# 2
# 0

# %%
data = 10, 20, 30

a, b, c = data
print(a)  
print(b)  
print(c)
# Out:
# 10
# 20
# 30

# %%
x = 5
y = 10
x, y = y, x
print(x, y)
# Out:
# 10 5
